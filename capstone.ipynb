# %% [markdown]
# <a href="https://colab.research.google.com/github/mugishaalex24682-cloud/bcs3101-capstone/blob/main/capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BCS3101 Capstone — Heart Disease Prediction
# Name: MUGISHA ALEX
# Reg Number: 2024/A/KCS/5461/F

print("Environment ready.")
# Out:
# Environment ready.
